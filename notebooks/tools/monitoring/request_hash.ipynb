# %% [markdown]
# # request_hash
#
# Deterministic SHA-256 hash of (method, url, params, body) for deduplicating API call logs.

# %%
# TODO: implement
import hashlib, json as _json

# def request_hash(method: str, url: str, params: dict, body: dict) -> str:
#     payload = f"{method}|{url}|{_json.dumps(params, sort_keys=True)}|{_json.dumps(body, sort_keys=True)}"
#     return hashlib.sha256(payload.encode()).hexdigest()
