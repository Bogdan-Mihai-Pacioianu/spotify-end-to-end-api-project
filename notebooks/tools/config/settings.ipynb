# %% [markdown]
# # settings
#
# Global constants: catalog/schema names, secret scope, API base URL, raw file paths.

# %%
# TODO: implement
# Catalog & schema names
# CATALOG = "spotify_etl"
# RAW_SCHEMA = "raw"
# BRONZE_SCHEMA = "bronze"
# SILVER_SCHEMA = "silver"
# GOLD_SCHEMA = "gold"

# Secret scope
# SECRET_SCOPE = "spotify_secrets"

# Spotify API
# SPOTIFY_API_BASE = "https://api.spotify.com"
# TOKEN_URL = "https://accounts.spotify.com/api/token"

# Raw file path builder
# def raw_base_path(entity, ingestion_date, run_id):
#     return f"/Workspace/Users/.../data/raw/{entity}/ingestion_date={ingestion_date}/run_id={run_id}"
