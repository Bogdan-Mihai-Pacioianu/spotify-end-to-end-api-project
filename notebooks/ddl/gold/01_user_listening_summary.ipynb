# %% [markdown]
# # 01_user_listening_summary
#
# DDL: gold_user_listening_summary — Aggregate: total tracks, artists, minutes, favorites.

# %%
# TODO: implement
catalog = "spotify_etl"
layer = "gold"
table = "gold_user_listening_summary"

# spark.sql(f"""CREATE TABLE IF NOT EXISTS {catalog}.{layer}.{table} (...) USING DELTA...""")
