# %%
CREATE TABLE IF NOT EXISTS spotify_etl.gold.gold_user_listening_summary (
  user_id STRING,
  total_tracks BIGINT,
  unique_artists BIGINT,
  total_minutes DOUBLE,
  favorite_artist STRING,
  top_track STRING
)
USING DELTA
TBLPROPERTIES (
  delta.enableChangeDataFeed = true,
  delta.columnMapping.mode = 'name'
);
