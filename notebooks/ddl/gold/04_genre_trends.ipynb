# %%
CREATE TABLE IF NOT EXISTS spotify_etl.gold.gold_genre_trends (
  genre STRING,
  month STRING,
  total_plays BIGINT,
  avg_popularity DOUBLE,
  unique_users BIGINT
)
USING DELTA
TBLPROPERTIES (
  delta.enableChangeDataFeed = true,
  delta.columnMapping.mode = 'name'
);
