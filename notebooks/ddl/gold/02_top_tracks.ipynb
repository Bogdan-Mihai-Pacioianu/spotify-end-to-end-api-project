# %%
CREATE TABLE IF NOT EXISTS spotify_etl.gold.gold_top_tracks (
  track_id STRING,
  track_name STRING,
  artist_name STRING,
  play_count BIGINT,
  total_minutes DOUBLE,
  popularity INT
)
USING DELTA
TBLPROPERTIES (
  delta.enableChangeDataFeed = true,
  delta.columnMapping.mode = 'name'
);
