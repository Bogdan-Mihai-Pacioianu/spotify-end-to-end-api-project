# %% [markdown]
# # 05_listening_patterns
#
# DDL: gold_listening_patterns — Listening patterns by hour and day of week.

# %%
# TODO: implement
catalog = "spotify_etl"
layer = "gold"
table = "gold_listening_patterns"

# spark.sql(f"""CREATE TABLE IF NOT EXISTS {catalog}.{layer}.{table} (...) USING DELTA...""")
