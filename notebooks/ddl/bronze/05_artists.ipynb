# %%
CREATE TABLE IF NOT EXISTS spotify_etl.bronze.bronze_artists (
  artist_id STRING,
  artist_name STRING,
  genres ARRAY<STRING>,
  followers BIGINT,
  popularity INT,
  uri STRING
)
USING DELTA PARTITIONED BY (processing_date)
TBLPROPERTIES (
  delta.enableChangeDataFeed = true
);
