# %% [markdown]
# # 03_playlist_tracks
#
# DDL: bronze_playlist_tracks — Raw playlist-to-track mappings.

# %%
# TODO: implement
catalog = "spotify_etl"
layer = "bronze"
table = "bronze_playlist_tracks"

# spark.sql(f"""CREATE TABLE IF NOT EXISTS {catalog}.{layer}.{table} (...) USING DELTA...""")
