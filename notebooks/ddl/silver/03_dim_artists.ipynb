# %%
CREATE TABLE IF NOT EXISTS spotify_etl.silver.dim_artists (
  artist_id STRING,
  artist_name STRING,
  genres ARRAY<STRING>,
  followers BIGINT,
  popularity INT,
  uri STRING
)
USING DELTA
TBLPROPERTIES (
  delta.enableChangeDataFeed = true,
  delta.columnMapping.mode = 'name'
);
