# %% [markdown]
# # 01_fct_plays
#
# DDL: fct_plays — Fact: play events, deduplicated by play_id (SHA256).

# %%
# TODO: implement
catalog = "spotify_etl"
layer = "silver"
table = "fct_plays"

# spark.sql(f"""CREATE TABLE IF NOT EXISTS {catalog}.{layer}.{table} (...) USING DELTA...""")
