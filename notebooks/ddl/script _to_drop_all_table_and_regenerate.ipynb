# %%
# %sql
-- Decoment code in case i want to delete all

DROP SCHEMA IF EXISTS spotify_etl.raw CASCADE;
DROP SCHEMA IF EXISTS spotify_etl.bronz CASCADE;
DROP SCHEMA IF EXISTS spotify_etl.silver CASCADE;
DROP SCHEMA IF EXISTS spotify_etl.gold CASCADE;

# %%
# %sql
-- DROP CATALOG IF EXISTS spotify_etl CASCADE;
CREATE CATALOG IF NOT EXISTS spotify_etl;

CREATE SCHEMA  IF NOT EXISTS spotify_etl.raw;
CREATE SCHEMA IF NOT EXISTS spotify_etl.bronze;
CREATE SCHEMA IF NOT EXISTS spotify_etl.silver;
CREATE SCHEMA IF NOT EXISTS  spotify_etl.gold;
